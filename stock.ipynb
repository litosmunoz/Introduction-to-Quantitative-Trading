# %%
from sys import argv
import pandas as pd
import yfinance as yf
import mplfinance as mpf
import sqlite3
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## NASDAQ

# %%
ndx = yf.download('^IXIC', start = "2020-11-10", end = "2022-11-24")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
mpf.plot(ndx, type = 'candle', mav=(21, 55), volume = True)

# %%
intraday_ndx = yf.download(tickers= '^IXIC', period = "5d", interval = "5m")
iday = intraday_ndx.loc["2022-11-21 11:00":"2022-11-24 12:00", :]
mpf.plot(iday, type="candle", mav=(12, 21), volume = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## SP 500

# %%
spx = yf.download('^GSPC', start = "2020-11-10", end = "2022-11-24")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spx.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-11-17  3919.260010  3954.330078  3906.540039  3946.560059  3946.560059
# 2022-11-18  3966.389893  3979.889893  3935.979980  3965.340088  3965.340088
# 2022-11-21  3956.229980  3962.000000  3933.340088  3949.939941  3949.939941
# 2022-11-22  3965.510010  4005.879883  3956.879883  4003.580078  4003.580078
# 2022-11-23  4000.300049  4033.780029  3998.659912  4027.260010  4027.260010
#
#                 Volume
# Date
# 2022-11-17  4051780000
# 2022-11-18  4037360000
# 2022-11-21  3850690000
# 2022-11-22  3887990000
# 2022-11-23  3279720000

# %%
mpf.plot(spx, type = 'candle', mav=(21,55), volume = True, style = 'default')

# %%
intraday_spx = yf.download(tickers= '^GSPC', period = "5d", interval = "5m")
iday_spx = intraday_spx.loc["2022-11-20 11:00":"2022-11-24 12:00", :]
mpf.plot(iday_spx, type="candle", mav=(12, 21), volume = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#con = sqlite3.connect("market_data.sqlite")

# %%
#This uses yfinance, moves the date to a column, renames the columns, and adds the symbol.
#def get_stock_data(symbol, start, end):
    #data = yf.download(symbol, start= start, end= end)
    #data.reset_index(inplace = True)
    #data.rename(columns = {"Date":"date", "Open": "open", "Low":"low", "Close":"close", "Adj Close": "adj_close", "Volume":"volume"}, inplace = True)
    #data["symbol"]=symbol
    #return data

# %%
#Create a function that uses `get_stock_data` to get a range of stock data and insert it into the market database.
#The function uses pandas to connect to the database and insert the data in the DataFrame into the database.
#Finally, get the last trading day's data.
#def save_data_range (symbol, start, end):
    #data = get_stock_data(symbol, start, end)
    #data.to_sql(
        #"stock_data",
        # con,
        # if_exists="append",
         #index=False)

# %%
#Create a function that inserts the last trading day into the database.
#This is useful for automating the script to get the current day's data.
#def save_last_trading_session (symbol):
    #today = pd.Timestamp.today()
    #data = get_stock_data(symbol, today, today)
    #data.to_sql(
        #"stock_data",
        #con,
        #if_exists="append",
        #index=False)

# %%
#save_data_range("NDX", "1990-01-01", "2022-11-16")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#ndx = pd.read_sql_query("Select * from stock_data where symbol ='NDX'", con)

# %%
#ndx.head()
# Out:
#                   date         open         High         low        close  \
# 0  2000-01-03 00:00:00  3755.739990  3836.860107  3643.25000  3790.550049
# 1  2000-01-04 00:00:00  3766.570068  3766.570068  3542.72998  3546.199951
# 2  2000-01-05 00:00:00  3543.129883  3576.169922  3371.75000  3507.310059
# 3  2000-01-06 00:00:00  3488.310059  3513.550049  3334.02002  3340.810059
# 4  2000-01-07 00:00:00  3337.260010  3529.750000  3314.75000  3529.600098
#
#      adj_close      volume symbol
# 0  3790.550049  1510070000    NDX
# 1  3546.199951  1511840000    NDX
# 2  3507.310059  1735670000    NDX
# 3  3340.810059  1598320000    NDX
# 4  3529.600098  1634930000    NDX

# %%
#save_data_range("SPY", "1995-01-01", "2022-11-16")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#spy = pd.read_sql_query("Select * from stock_data where symbol ='SPY'", con)
#spy[:10]
# Out:
#                   date       open       High         low      close  \
# 0  2000-01-03 00:00:00  148.25000  148.25000  143.875000  145.43750
# 1  2000-01-04 00:00:00  143.53125  144.06250  139.640625  139.75000
# 2  2000-01-05 00:00:00  139.93750  141.53125  137.250000  140.00000
# 3  2000-01-06 00:00:00  139.62500  141.50000  137.750000  137.75000
# 4  2000-01-07 00:00:00  140.31250  145.75000  140.062500  145.75000
# 5  2000-01-10 00:00:00  146.25000  146.90625  145.031250  146.25000
# 6  2000-01-11 00:00:00  145.81250  146.09375  143.500000  144.50000
# 7  2000-01-12 00:00:00  144.59375  144.59375  142.875000  143.06250
# 8  2000-01-13 00:00:00  144.46875  145.75000  143.281250  145.00000
# 9  2000-01-14 00:00:00  146.53125  147.46875  145.968750  146.96875
#
#    adj_close    volume symbol
# 0  95.746429   8164300    SPY
# 1  92.002220   8089800    SPY
# 2  92.166756  12177900    SPY
# 3  90.685509   6227200    SPY
# 4  95.952179   8066500    SPY
# 5  96.281349   5741700    SPY
# 6  95.129257   7503700    SPY
# 7  94.182945   6907700    SPY
# 8  95.458443   5158300    SPY
# 9  96.754547   7437300    SPY
